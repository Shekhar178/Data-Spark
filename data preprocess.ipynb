# %%
#Importing Libraries
import pandas as pd

# %%
sales= pd.read_csv(r"C:\Users\DELL\Desktop\data spark\data\sales.csv")
customers= pd.read_csv(r"C:\Users\DELL\Desktop\data spark\data\customers.csv", encoding='ISO-8859-1')
products= pd.read_csv(r"C:\Users\DELL\Desktop\data spark\data\products.csv")
stores= pd.read_csv(r"C:\Users\DELL\Desktop\data spark\data\stores.csv")
exrates= pd.read_csv(r"C:\Users\DELL\Desktop\data spark\data\exchange_rates.csv")
#customer data has some alphabets of other languages so encodings = 'ISO-8859-1'

# %%
#preview
sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
#checking null values
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   Delivery Date  13165 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 4.3+ MB

# %%
sales.fillna('Not Available', inplace=True)

# %%
#converting to necessary formats
sales['Order Date']=pd.to_datetime(sales['Order Date'], format = '%m/%d/%Y')
sales['Currency Code']= sales['Currency Code'].astype(str)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  datetime64[ns]
#  3   Delivery Date  62884 non-null  object
#  4   CustomerKey    62884 non-null  int64
#  5   StoreKey       62884 non-null  int64
#  6   ProductKey     62884 non-null  int64
#  7   Quantity       62884 non-null  int64
#  8   Currency Code  62884 non-null  object
# dtypes: datetime64[ns](1), int64(6), object(2)
# memory usage: 4.3+ MB

# %%
sales
# Out:
#        Order Number  Line Item Order Date  Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01  Not Available       265598
# 1            366001          1 2016-01-01      1/13/2016      1269051
# 2            366001          2 2016-01-01      1/13/2016      1269051
# 3            366002          1 2016-01-01      1/12/2016       266019
# 4            366002          2 2016-01-01      1/12/2016       266019
# ...             ...        ...        ...            ...          ...
# 62879       2243030          1 2021-02-20  Not Available      1216913
# 62880       2243031          1 2021-02-20      2/24/2021       511229
# 62881       2243032          1 2021-02-20      2/23/2021       331277
# 62882       2243032          2 2021-02-20      2/23/2021       331277
# 62883       2243032          3 2021-02-20      2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
#preview
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#      Open Date
# 0   01-01-2008
# 1   01-12-2008
# 2   01-07-2012
# 3   01-01-2010
# 4   12-09-2015
# ..         ...
# 62  03-06-2008
# 63  01-01-2010
# 64  01-01-2012
# 65  01-01-2014
# 66  01-01-2010
#
# [67 rows x 5 columns]

# %%
#checking null values
stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   StoreKey       67 non-null     int64
#  1   Country        67 non-null     object
#  2   State          67 non-null     object
#  3   Square Meters  66 non-null     float64
#  4   Open Date      67 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
#converting to necessary formats
stores['Open Date'] = pd.to_datetime(stores['Open Date'], format = '%m/%d/%Y', errors= 'coerce')
stores['Country']= stores['Country'].astype(str)
stores['State']= stores['State'].astype(str)

# %%
#filling missing values
stores['Square Meters'].fillna(0, inplace= True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21204\308898225.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   stores['Square Meters'].fillna(0, inplace= True)

# %%
#preview
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# 0     Silver        $6.62         $12.99              101
# 1       Blue        $6.62         $12.99              101
# 2      White        $7.40         $14.52              101
# 3     Silver       $11.00         $21.57              101
# 4        Red       $11.00         $21.57              101
# ...      ...           ...            ...             ...
# 2512     Red       $43.07        $129.99              505
# 2513   White       $43.07        $129.99              505
# 2514   White        $1.71          $3.35              505
# 2515   Black        $1.71          $3.35              505
# 2516  Silver        $1.71          $3.35              505
#
#                   Subcategory  CategoryKey     Category
# 0                     MP4&MP3            1        Audio
# 1                     MP4&MP3            1        Audio
# 2                     MP4&MP3            1        Audio
# 3                     MP4&MP3            1        Audio
# 4                     MP4&MP3            1        Audio
# ...                       ...          ...          ...
# 2512  Cell phones Accessories            5  Cell phones
# 2513  Cell phones Accessories            5  Cell phones
# 2514  Cell phones Accessories            5  Cell phones
# 2515  Cell phones Accessories            5  Cell phones
# 2516  Cell phones Accessories            5  Cell phones
#
# [2517 rows x 10 columns]

# %%
#checking null values
products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
#converting to necessary formats and replacing unnecessary strings
products['Unit Cost USD']= products['Unit Cost USD'].replace('[\$,]', '',regex=True) .astype(float)
products['Unit Price USD']= products['Unit Price USD'].replace('[\$,]','',regex=True).astype(float)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# <>:2: SyntaxWarning: invalid escape sequence '\$'
# <>:3: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21204\803746463.py:2: SyntaxWarning: invalid escape sequence '\$'
#   products['Unit Cost USD']= products['Unit Cost USD'].replace('[\$,]', '',regex=True) .astype(float)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21204\803746463.py:3: SyntaxWarning: invalid escape sequence '\$'
#   products['Unit Price USD']= products['Unit Price USD'].replace('[\$,]','',regex=True).astype(float)

# %%
#preview
exrates
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
#no null values
exrates.isnull().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
exrates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
#converting to necessary formats
exrates['Date']= pd.to_datetime(exrates['Date'], format = '%m/%d/%Y', errors= 'coerce')

# %%
#preview
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# 1      Western Australia     6522      Australia      Australia   9/27/1979
# 2               Victoria     3380      Australia      Australia   5/26/1947
# 3        South Australia     5223      Australia      Australia   9/17/1957
# 4               Victoria     3698      Australia      Australia  11/19/1965
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America   3/25/1936
# 15262           Virginia    22101  United States  North America   2/16/1992
# 15263     North Carolina    28405  United States  North America   11/9/1937
# 15264         California    92501  United States  North America  10/12/1937
# 15265           Michigan    48302  United States  North America   8/18/1965
#
# [15266 rows x 10 columns]

# %%
#checking null values
customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15256 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
def convert_date(date_str):
    try:
        return pd.to_datetime(date_str, format='%m/%d/%Y', errors='coerce').strftime('%m/%d/%Y')
    except ValueError:
        try:
            return pd.to_datetime(date_str, format='%d-%m-%Y', errors='coerce').strftime('%m/%d/%Y')
        except ValueError:
            return date_str 
customers['Birthday'] = customers['Birthday'].apply(convert_date)

# %%
#converting to necessary formats
customers['Birthday']= pd.to_datetime(customers['Birthday'], format='%m/%d/%Y', errors = 'coerce')

# %%
#filling null values
customers['State Code'].fillna('Not Available', inplace = True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21204\2856024365.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers['State Code'].fillna('Not Available', inplace = True)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(8)
# memory usage: 1.2+ MB

# %%
#merging all datas
overall= sales

# %%
overall = pd.merge(overall,customers, on = 'CustomerKey', how ='inner')

# %%
overall.dropna(inplace=True)

# %%
overall
# Out:
#        Order Number  Line Item Order Date  Delivery Date  CustomerKey  \
# 0            366000          1 2016-01-01  Not Available       265598
# 1            366001          1 2016-01-01      1/13/2016      1269051
# 2            366001          2 2016-01-01      1/13/2016      1269051
# 3            366002          1 2016-01-01      1/12/2016       266019
# 4            366002          2 2016-01-01      1/12/2016       266019
# ...             ...        ...        ...            ...          ...
# 62879       2243030          1 2021-02-20  Not Available      1216913
# 62880       2243031          1 2021-02-20      2/24/2021       511229
# 62881       2243032          1 2021-02-20      2/23/2021       331277
# 62882       2243032          2 2021-02-20      2/23/2021       331277
# 62883       2243032          3 2021-02-20      2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code  Gender  \
# 0            10        1304         1           CAD    Male
# 1             0        1048         2           USD    Male
# 2             0        2007         1           USD    Male
# 3             0        1106         7           CAD  Female
# 4             0         373         1           CAD  Female
# ...         ...         ...       ...           ...     ...
# 62879        43         632         3           USD    Male
# 62880         0          98         4           EUR  Female
# 62881         0        1613         2           CAD    Male
# 62882         0        1717         2           CAD    Male
# 62883         0         464         7           CAD    Male
#
#                     Name                  City State Code              State  \
# 0           Tyler Vaught                London         ON            Ontario
# 1         Frank Upchurch               Auberry         CA         California
# 2         Frank Upchurch               Auberry         CA         California
# 3             Joan Roche              Red Deer         AB            Alberta
# 4             Joan Roche              Red Deer         AB            Alberta
# ...                  ...                   ...        ...                ...
# 62879      Donald Woodie          Garden Grove         CA         California
# 62880  Gabriele Thalberg  Stuttgart Frauenkopf         BW  Baden-Württemberg
# 62881   William Rochelle               Calgary         AB            Alberta
# 62882   William Rochelle               Calgary         AB            Alberta
# 62883   William Rochelle               Calgary         AB            Alberta
#
#       Zip Code        Country      Continent   Birthday
# 0      N5W 5K6         Canada  North America 1971-03-23
# 1        93602  United States  North America 1995-11-20
# 2        93602  United States  North America 1995-11-20
# 3      T4N 2A6         Canada  North America 1962-08-24
# 4      T4N 2A6         Canada  North America 1962-08-24
# ...        ...            ...            ...        ...
# 62879    92643  United States  North America 1939-04-16
# 62880    70184        Germany         Europe 1940-03-10
# 62881  T2T 0C6         Canada  North America 1993-05-25
# 62882  T2T 0C6         Canada  North America 1993-05-25
# 62883  T2T 0C6         Canada  North America 1993-05-25
#
# [62884 rows x 18 columns]

# %%
overall=pd.merge(overall,exrates,left_on=['Order Date','Currency Code'],right_on=['Date','Currency'],how='inner')

# %%
overall = pd.merge(overall,products,on='ProductKey',how='inner')

# %%
overall= pd.merge(overall,stores,on=['StoreKey','Country','State'],how='inner')

# %%
overall
# Out:
#       Order Number  Line Item Order Date  Delivery Date  CustomerKey  \
# 0           366005          1 2016-01-01  Not Available       844003
# 1           367006          1 2016-01-02  Not Available       693285
# 2           367010          1 2016-01-02  Not Available      1322959
# 3           367010          2 2016-01-02  Not Available      1322959
# 4           369007          1 2016-01-04  Not Available       571622
# ...            ...        ...        ...            ...          ...
# 6176       2243014          1 2021-02-20  Not Available      1453427
# 6177       2243014          2 2021-02-20  Not Available      1453427
# 6178       2243014          3 2021-02-20  Not Available      1453427
# 6179       2243021          1 2021-02-20  Not Available      1783631
# 6180       2243021          2 2021-02-20  Not Available      1783631
#
#       StoreKey  ProductKey  Quantity Currency Code  Gender  ...  \
# 0           33         421         4           EUR    Male  ...
# 1           18        2445         3           EUR  Female  ...
# 2           66         917         1           USD    Male  ...
# 3           66          39         1           USD    Male  ...
# 4           20        2510         3           EUR    Male  ...
# ...        ...         ...       ...           ...     ...  ...
# 6176        50         423         1           USD    Male  ...
# 6177        50        1617         1           USD    Male  ...
# 6178        50        2506         4           USD    Male  ...
# 6179        55        1147         4           USD    Male  ...
# 6180        55        1531         4           USD    Male  ...
#
#                   Brand   Color Unit Cost USD Unit Price USD SubcategoryKey  \
# 0       Adventure Works  Silver        215.68         469.00            303
# 1               Litware   Green          2.54           4.99            808
# 2      Southridge Video   White         59.31         179.00            308
# 3               Contoso   Green         99.14         299.23            101
# 4               Contoso   White          2.07           4.06            505
# ...                 ...     ...           ...            ...            ...
# 6176    Adventure Works   Black        275.46         599.00            303
# 6177            Contoso  Silver         26.67          57.99            602
# 6178            Contoso    Pink          2.42           4.74            505
# 6179           Fabrikam   Black        301.21         655.00            405
# 6180  The Phone Company   Black        128.88         389.00            504
#
#                   Subcategory CategoryKey                       Category  \
# 0                    Desktops           3                      Computers
# 1                        Fans           8                Home Appliances
# 2       Computers Accessories           3                      Computers
# 3                     MP4&MP3           1                          Audio
# 4     Cell phones Accessories           5                    Cell phones
# ...                       ...         ...                            ...
# 6176                 Desktops           3                      Computers
# 6177                Movie DVD           6  Music, Movies and Audio Books
# 6178  Cell phones Accessories           5                    Cell phones
# 6179               Camcorders           4         Cameras and camcorders
# 6180      Smart phones & PDAs           5                    Cell phones
#
#      Square Meters  Open Date
# 0           1540.0        NaT
# 1            310.0        NaT
# 2            840.0        NaT
# 3            840.0        NaT
# 4           1715.0 2012-12-15
# ...            ...        ...
# 6176        2000.0        NaT
# 6177        2000.0        NaT
# 6178        2000.0        NaT
# 6179        2000.0 2009-12-15
# 6180        2000.0 2009-12-15
#
# [6181 rows x 32 columns]

# %%
col=list(overall.columns)
col1=[]
for c in col:
    col1.append(c.replace(' ','_').lower())
    
overall.columns=col1

# %%
col=list(stores.columns)
col1=[]
for c in col:
    col1.append(c.replace(' ','_').lower())
    
stores.columns=col1

# %%
col1
# Out:
# ['storekey', 'country', 'state', 'square_meters', 'open_date']

# %%
overall.columns
# Out:
# Index(['order_number', 'line_item', 'order_date', 'delivery_date',
#        'customerkey', 'storekey', 'productkey', 'quantity', 'currency_code',
#        'gender', 'name', 'city', 'state_code', 'state', 'zip_code', 'country',
#        'continent', 'birthday', 'date', 'currency', 'exchange', 'product_name',
#        'brand', 'color', 'unit_cost_usd', 'unit_price_usd', 'subcategorykey',
#        'subcategory', 'categorykey', 'category', 'square_meters', 'open_date'],
#       dtype='object')

# %%
overall.isnull().sum()
# Out:
# order_number      0
# line_item         0
# order_date        0
# customerkey       0
# storekey          0
# productkey        0
# quantity          0
# currency_code     0
# gender            0
# name              0
# city              0
# state_code        0
# state             0
# zip_code          0
# country           0
# continent         0
# birthday          0
# date              0
# currency          0
# exchange          0
# product_name      0
# brand             0
# color             0
# unit_cost_usd     0
# unit_price_usd    0
# subcategorykey    0
# subcategory       0
# categorykey       0
# category          0
# square_meters     0
# open_date         0
# dtype: int64

# %%
overall.dtypes
# Out:
# order_number               int64
# line_item                  int64
# order_date        datetime64[ns]
# delivery_date             object
# customerkey                int64
# storekey                   int64
# productkey                 int64
# quantity                   int64
# currency_code             object
# gender                    object
# name                      object
# city                      object
# state_code                object
# state                     object
# zip_code                  object
# country                   object
# continent                 object
# birthday          datetime64[ns]
# date              datetime64[ns]
# currency                  object
# exchange                 float64
# product_name              object
# brand                     object
# color                     object
# unit_cost_usd            float64
# unit_price_usd           float64
# subcategorykey             int64
# subcategory               object
# categorykey                int64
# category                  object
# square_meters            float64
# open_date         datetime64[ns]
# dtype: object

# %%
overall.to_csv(r'C:\Users\DELL\Desktop\data spark\overall.csv', index=False)

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
 
host = "localhost"
port = "3306"
username = "root"
password = "guvi"
database = "ds"
 
engine_string = f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
engine = create_engine(engine_string)
 
table_name = "overall"
overall.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")

table_name = "customers"
customers.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")

table_name = "products"
products.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")

table_name = "exrates"
exrates.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")

table_name = "stores"
stores.to_sql(table_name, engine,if_exists='replace',index=False)
print(f"successfully imported {table_name} to sql")
# Out:
# successfully imported overall to sql
# successfully imported customers to sql
# successfully imported products to sql
# successfully imported exrates to sql
# successfully imported stores to sql
